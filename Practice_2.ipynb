# %% [markdown]
# <a href="https://colab.research.google.com/github/sophiabj/Data-Science-Projects/blob/master/Practice_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
data = pd.read_csv('https://raw.githubusercontent.com/WalePhenomenon/climate_change/master/fuel_ferc1.csv', error_bad_lines=False)

# %%
#Understanding the data

# %%
data.head()
# Out:
#                 record_id  ...  fuel_cost_per_mmbtu
# 0   f1_fuel_1994_12_1_0_7  ...                1.121
# 1  f1_fuel_1994_12_1_0_10  ...                1.120
# 2   f1_fuel_1994_12_2_0_1  ...                1.650
# 3   f1_fuel_1994_12_2_0_7  ...                1.970
# 4  f1_fuel_1994_12_2_0_10  ...                2.570
#
# [5 rows x 11 columns]

# %%
data.tail()
# Out:
#                      record_id  ...  fuel_cost_per_mmbtu
# 29518  f1_fuel_2018_12_12_0_13  ...                 9.03
# 29519   f1_fuel_2018_12_12_1_1  ...                 6.95
# 29520  f1_fuel_2018_12_12_1_10  ...                 8.99
# 29521  f1_fuel_2018_12_12_1_13  ...                 1.11
# 29522  f1_fuel_2018_12_12_1_14  ...                11.68
#
# [5 rows x 11 columns]

# %%
data.shape
# Out:
# (29523, 11)

# %%
data.describe()
# Out:
#        utility_id_ferc1  ...  fuel_cost_per_mmbtu
# count      29523.000000  ...         29523.000000
# mean         118.601836  ...            19.304354
# std           74.178353  ...          2091.540939
# min            1.000000  ...           -41.501000
# 25%           55.000000  ...             1.940000
# 50%          122.000000  ...             4.127000
# 75%          176.000000  ...             7.745000
# max          514.000000  ...        359278.000000
#
# [8 rows x 7 columns]

# %%
data.columns
# Out:
# Index(['record_id', 'utility_id_ferc1', 'report_year', 'plant_name_ferc1',
#        'fuel_type_code_pudl', 'fuel_unit', 'fuel_qty_burned',
#        'fuel_mmbtu_per_unit', 'fuel_cost_per_unit_burned',
#        'fuel_cost_per_unit_delivered', 'fuel_cost_per_mmbtu'],
#       dtype='object')

# %% [markdown]
# #Check for unique values

# %%
data.nunique()
# Out:
# record_id                       29523
# utility_id_ferc1                  185
# report_year                        25
# plant_name_ferc1                 2315
# fuel_type_code_pudl                 6
# fuel_unit                           9
# fuel_qty_burned                 26432
# fuel_mmbtu_per_unit             11227
# fuel_cost_per_unit_burned       19416
# fuel_cost_per_unit_delivered    16675
# fuel_cost_per_mmbtu             12605
# dtype: int64

# %%
data['report_year'].unique()
# Out:
# array([1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004,
#        2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015,
#        2016, 2017, 2018])

# %%
data['fuel_type_code_pudl'].unique()
# Out:
# array(['coal', 'gas', 'nuclear', 'oil', 'waste', 'other'], dtype=object)

# %% [markdown]
# Cleaning the data

# %%
data.isnull().sum()
# Out:
# record_id                         0
# utility_id_ferc1                  0
# report_year                       0
# plant_name_ferc1                  0
# fuel_type_code_pudl               0
# fuel_unit                       180
# fuel_qty_burned                   0
# fuel_mmbtu_per_unit               0
# fuel_cost_per_unit_burned         0
# fuel_cost_per_unit_delivered      0
# fuel_cost_per_mmbtu               0
# dtype: int64

# %% [markdown]
# Relationship analysis

# %%
correlation = data.corr()

# %%
sns.heatmap(correlation, xticklabels=correlation.columns, yticklabels=correlation.columns, annot=True)

# %%
correlation.loc['fuel_cost_per_unit_burned'].sort_values()
# Out:
# utility_id_ferc1               -0.037863
# fuel_qty_burned                -0.018535
# fuel_mmbtu_per_unit            -0.010034
# fuel_cost_per_mmbtu            -0.000437
# fuel_cost_per_unit_delivered    0.011007
# report_year                     0.013599
# fuel_cost_per_unit_burned       1.000000
# Name: fuel_cost_per_unit_burned, dtype: float64

# %%
sns.pairplot(data)

# %%
sns.distplot(data['report_year'])

# %%
data.groupby('report_year').sum()
# Out:
#              utility_id_ferc1  ...  fuel_cost_per_mmbtu
# report_year                    ...
# 1994                   131059  ...           3812.41711
# 1995                   132277  ...           3445.47398
# 1996                   118281  ...           2933.11773
# 1997                   118553  ...           3406.15391
# 1998                   121599  ...           3072.87907
# 1999                   113634  ...           2877.26381
# 2000                   152518  ...           5778.13677
# 2001                   153935  ...           6254.76430
# 2002                   145027  ...           7502.66915
# 2003                   149317  ...           8748.18305
# 2004                   144379  ...          10062.38345
# 2005                   153585  ...          11924.89239
# 2006                   145653  ...          12852.49312
# 2007                   146675  ...          13569.26878
# 2008                   148324  ...          15583.46077
# ...

# %%
y = data.groupby(['report_year','fuel_type_code_pudl'])['fuel_cost_per_unit_burned'].sum()
y
# Out:
# report_year  fuel_type_code_pudl
# 1994         coal                    14984.572
#              gas                     10792.496
#              nuclear                227983.354
#              oil                      9362.194
#              other                     116.737
#                                        ...
# 2018         coal                     9488.197
#              gas                      4322.494
#              nuclear                173267.161
#              oil                     33836.602
#              waste                     660.972
# Name: fuel_cost_per_unit_burned, Length: 148, dtype: float64

# %%
f = y.loc[[1994,1998], 'coal']
f
# Out:
# report_year  fuel_type_code_pudl
# 1994         coal                   14984.572
# 1998         coal                   11902.597
# Name: fuel_cost_per_unit_burned, dtype: float64

# %%
f.pct_change()
# Out:
# report_year  fuel_type_code_pudl
# 1994         coal                        NaN
# 1998         coal                  -0.205677
# Name: fuel_cost_per_unit_burned, dtype: float64
